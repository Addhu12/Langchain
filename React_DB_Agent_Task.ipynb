# %%
import sqlite3
import os
import sys

DB_DIR = "SalesDB"
DB_PATH = os.path.join(DB_DIR, "sales.db")

os.makedirs(DB_DIR, exist_ok = True)

conn = sqlite3.connect(DB_PATH)

cursor = conn.cursor()
print("DB connected at:", DB_PATH)



cursor.execute("""
    CREATE TABLE IF NOT EXISTS orders (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    customer_name TEXT NOT NULL,
    product_name TEXT NOT NULL,
    quantity INTEGER NOT NULL,
    price REAL NOT NULL,
    total REAL NOT NULL
    )
""")

cursor.execute("""
INSERT INTO orders (customer_name, product_name, quantity, price, total) VALUES
("John Doe", "Laptop", 1, 1000.00, 1000.00),
("Jane Smith", "Smartphone", 2, 500.00, 1000.00),
("Bob Johnson", "Tablet", 3, 200.00, 600.00)
""")

conn.commit()
conn.close()
# Out:
# DB connected at: SalesDB\sales.db

# %%
import os

os.remove("SalesDB")
